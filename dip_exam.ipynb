# %% [markdown]
# # NEAF DIP EXAM
# name:

# %% [markdown]
# ---
# ### Please achieve the following image transformation: change image A into image B.

# %% [markdown]
# ### keywords:
# cv2.blur(img, (3, 3))
# cv2.dilate(img, kernel)
# cv2.inRange(img, np.array([16, 26, 120]), np.array([74, 255, 255]))
# cv2.equalizeHist(gray_img)
# cv2.bitwise_and(img1, img2, mask)
# cv2.IMREAD_GRAYSCALE
# cv2.drawContours(img, contours, -1, (0, 255, 0), 1)
# cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# cv2.rectangle(result, (X, Y), (X+W, Y+H), (0, 0, 255), 2)
# cv2.medianBlur(img, 3)
# cv2.boundingRect
# cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
# cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
# cv2.imwrite('123.jpg', img)
# cv2.GaussianBlur(img, (5, 5), 0)
# cv2.erode(img, kernel)
# cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# cv2.contourArea(contour)

# %% [markdown]
# ---

# %% [markdown]
# ### library

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# ### 1. (5%)
# #### fig.a
# <img src="img/5.jpg" width="20%" heught="20%">
#
# #### fig.b
# <img src="img/6.jpg" width="20%" heught="20%">

# %%
# read image
img_a = cv2.imread("img/5.jpg")
img_a = cv2.cvtColor(img_a, cv2.COLOR_BGR2RGB)
#img_b = cv2.imread(img_a, cmap = 'gray')
#img_a = cv2.imread("input/lena.bmp", cv2.IMREAD_GRAYSCALE) # Read image as gray.

'''
enter your code
'''
# 載入 OpenCV 和 Matplotlib 模塊
import cv2
import matplotlib.pyplot as plt

# 讀取灰度圖像
img_b = cv2.imread("img/5.jpg", cv2.IMREAD_GRAYSCALE) # Read image as gray.

# 創建一個 10x5 英寸的圖形窗口
plt.figure(figsize=(10,5))

# 顯示原始圖像
plt.subplot(1,2,1)
#plt.imshow(img_b, cmap='gray')

# show image
plt.imshow(img_a)
plt.show()
plt.imshow(img_b, 'gray')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 2. (5%)
# #### fig.a
# <img src="img/1.jpg" width="15%" heught="15%">
#
# #### fig.b
# <img src="img/2.jpg" width="15%" heught="15%">

# %%
# read image
img_a = cv2.imread("img/1.jpg",cv2.IMREAD_GRAYSCALE )

'''
enter your code
'''

# 進行直方圖均衡化
img_b = cv2.equalizeHist(img_a)


# show image
plt.imshow(img_a, 'gray')
plt.show()
plt.imshow(img_b, 'gray')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 3. (5%)
# #### a圖
# <img src="img/3.jpg" width="20%" heught="20%">
#
# #### b圖
# <img src="img/4.jpg" width="20%" heught="20%">

# %%
# read image
img_a = cv2.imread("img/3.jpg")

'''
enter your code
'''
image_b1 = cv2.medianBlur(img_a, 3)

# show image
plt.imshow(img_a)
plt.show()
plt.imshow(image_b1)
plt.show()

# %% [markdown]
# ### 4. (10%)
# #### fig.a
# <img src="img/7.jpg" width="20%" heught="20%">
#
# #### fig.b
# <img src="img/8.jpg" width="20%" heught="20%">
#
# 1. Find the Beluga Whale contours in the  images.(5%)
# 2. Calculate the countours area.(5%)

# %%
pad_task1 = cv2.imread('C:/Users/user/Desktop/0827dip/2024_neaf_dip_exam/img/7.jpg', cv2.IMREAD_GRAYSCALE)
kernel = np.ones((3,3), np.uint8)
kernel1 = np.ones((11,11), np.uint8)
threshold = 138
threshold1 = 216
#208
#黑白反轉
_,image_binary_pad3 = cv2.threshold(255-pad_task1, threshold1, 255, cv2.THRESH_BINARY)

img_a = cv2.cvtColor(pad_task1 , cv2.COLOR_BGR2RGB)  

#膨脹收縮
dilation_img3 = cv2.dilate(image_binary_pad3, kernel, iterations=1)
close_img3 = cv2.erode(dilation_img3, kernel, iterations=1)
dilation_img3 = cv2.dilate(close_img3, kernel, iterations=1)
close_img4 = cv2.erode(close_img3, kernel, iterations=1)
dilation_img4 = cv2.dilate(close_img4, kernel, iterations=1)
close_img5 = cv2.erode(dilation_img4, kernel, iterations=1)

#dilation_img4 = cv2.dilate(close_img4, kernel, iterations=1)
# 顯示處理後的圖像
plt.figure(figsize=(10, 10))
plt.subplot(1, 6, 1)
plt.title('origin')
plt.imshow(img_a)
plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plt.title('origin')
plt.imshow(pad_task1, cmap='gray')
# 找到輪廓
contours, _ = cv2.findContours(dilation_img4, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
image_with_contours = cv2.cvtColor(pad_task1, cv2.COLOR_GRAY2BGR)

# 計算每個輪廓的面積並繪製
for i, contour in enumerate(contours):
    pad_area3 = cv2.contourArea(contour)
    
    if  200< pad_area3 < 1800000:
        # 複製原始圖像以繪製輪廓
        #print(f"輪廓 {i} 的面積是: {pad_area3}")
        print('The Beluga Whale area is ',pad_area3)
        cv2.drawContours(image_with_contours, contours, i, (255, 0, 0),10)
        plt.subplot(1, 6, 2)
        plt.title('result')
        plt.imshow(image_with_contours, cmap='gray')    
# show image

"""
plt.imshow(img_a)
plt.show()
plt.imshow(img_b)
plt.show()
"""
#print('The Beluga Whale area is ',pad_area3)
# Out:
# The Beluga Whale area is  479097.5
# '\nplt.imshow(img_a)\nplt.show()\nplt.imshow(img_b)\nplt.show()\n'
